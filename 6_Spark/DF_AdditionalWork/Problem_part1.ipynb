# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from pyspark.sql.types import *

# %% [markdown]
# ## Look at the data under `dataset/` and understand the below schema

# %%
compSchema = StructType([
    StructField("Date", StringType(), True),
    StructField("Open", DoubleType(), True),
    StructField("High", DoubleType(), True),
    StructField("Low", DoubleType(), True),
    StructField("Close", DoubleType(), True),
    StructField("Adjusted Close", DoubleType(), True),
    StructField("Script", StringType(), True)])

# %% [markdown]
# ## 1) Create a DF `initDf` by loading the data from dataset folder by confirming to above schema
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2) Find the maximum `HIGH` price per `Script` per year (`year` part of the `Date` column). Utilize DF `initDf`
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3) Find the average `HIGH` price per `Script` per year (`year` part of the `Date` column) and round it to 2 digits only. Utilize DF `initDf
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4) Find the maximum value of the `HIGH` price per `Script` per year (year part of the `Date` column). Utilize DF `initDf`. Use a Spark SQL query
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5) Use case for agg function
#
# ![image.png](attachment:image.png)
